# %% [markdown]
# # **Part 1 - Creating the Colab Notebook**
# ## **Step 1** - Access your Google Drive and create a folder to store your Colab Notebooks.
# ## **Step 2** - Instantiate a Google Colab Notetbook and place it in the Colab Notebook file.
# ## **Step 3** - Download the raw public health dataset as a csv file, https://uncch.instructure.com/courses/79778/files/9979460?wrap=1 .
# ## **Step 4** - Insert the downloaded csv file into the Colab Notebook.

# %% [markdown]
# # **Part 2** - Importing and Mounting
# ## **Step 1** - Input the import and mount statements with your google drive as the parameter in the exact format as the lines of code provided below.
# ## **Step 2** - Select the files button in the left sidebar to access your google drive.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # **Part 3** - Importing Pandas and Numpy
# ## **Step 1** - Using the exact import statements provided in the lines of code below to import the pandas and numpy functions that will allow you to create data structures for analyzation of formatted tabular data and perfrom algebraic operations.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Part 4** - Importing a CSV File
# ## **Step 1**- Name the csv file object that you will be instantiating, below I named mine data.
# ## **Step 2** - Next to the name of this object insert the folling segment of code: =pd.read_csv .
# ## **Step 3** - After the segment of code you inserted in the previous step you will insert a pair of parantheses with a pair of quotation marks in it.
# ## **Step 4** - Within the quotation marks referenced above insert the following code: /content/gdrive/MyDrive/Colab Notebooks/Name of CSV file .

# %%
data=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/CountyHealthData_2014-2015 (1).csv')

# %% [markdown]
# # **Part 5** - Filetering the Pacific Data
# ## **Step 1** - Type the name of the csv file object followed by the opening og a square bracket.
# ## **Step 2** - Repeat the above step next to the code you wrote in the previous step.
# ## **Step 3** - In a pair of quotation marks type the word Division, to isolate the data from the Division coloumn in the raw data set.
# ## **Step 4** - Insert a closing square bracket.
# ## **Step 5** - Type a double equal sign and a pair of quotation marks on this line with Pacific within the quotation marks, to isolate all of the rows of raw data in the Pacific division.
# ## **Step 6** - Insert a final closing square bracket for this line of code.

# %%
data[data["Division"]=="Pacific"]
# Out:
#      State Region Division                      County   FIPS  GEOID  \
# 0       AK   West  Pacific  Aleutians West Census Area   2016   2016
# 1       AK   West  Pacific  Aleutians West Census Area   2016   2016
# 2       AK   West  Pacific           Anchorage Borough   2020   2020
# 3       AK   West  Pacific           Anchorage Borough   2020   2020
# 4       AK   West  Pacific          Bethel Census Area   2050   2050
# ...    ...    ...      ...                         ...    ...    ...
# 5804    WA   West  Pacific              Whatcom County  53073  53073
# 5805    WA   West  Pacific              Whitman County  53075  53075
# 5806    WA   West  Pacific              Whitman County  53075  53075
# 5807    WA   West  Pacific               Yakima County  53077  53077
# 5808    WA   West  Pacific               Yakima County  53077  53077
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# ...

# %% [markdown]
# # **Part 6** - Creating a Subset for the Filtered Pacific Division Data
# ## **Step 1** - Write a name for the subset object that will store the filtered pacific divion and add an underscore followed by the word Subset.
# ## **Step 2** - Insert an equal sign and the exact same line of code as it was given in the previous part.

# %%
Pacific_Subset=data[data["Division"]=="Pacific"]

# %% [markdown]
# # **Part 7**- Converting the filtered subset into a CSV file
# ## **Step 1** - Type the name you instantiated the filtered Pacific division data as.
# ## **Step 2** - Next to thi code inert a the following code: to_csv("", ).
# ## **Step 3** - Within the quotation marks inert the following statement which will be the name of the csv file: Pacific_Subset.csv .
# ## **Step 4** - Finally after the comma within the parantheses type the follwing statement: index=False .

# %%
Pacific_Subset.to_csv("Pacific_Subset.csv", index=False)
